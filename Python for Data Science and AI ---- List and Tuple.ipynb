# %% [markdown]
# # Tuples
# * Tuples are an ordered sequence
# * Here is a Tuple "Ratings"
# * Tuples are written as comma-seperated elements within parenthess

# %% [markdown]
# Ratings = （10，9，6，5，10，8，9，6，2）

# %% [markdown]
# Tuple1 = （“disco”， 10， 1.2)
#
# Each element of a tuple can be accessed via an index:
# index|content|code
# --|:--:|--:
# 0 | "disco" |Tuple1[0]:"disco"
# 1 | 10      |Tuple1[1]:10
# 2 | 1.2     |Tuple1[2]:1.2

# %% [markdown]
# ## Slicing
# ("disco",10,1.2,"hard rock",10)
#
# tuple2[3:5]:("hard rock",10)
#
# notice that the last index is one larger than the index you want

# %% [markdown]
# Tuples are IMMUTABLE

# %% [markdown]
# ![%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.23.53.png](attachment:%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.23.53.png)

# %% [markdown]
# It can be viewed as a tree:

# %% [markdown]
# ![%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.26.09.png](attachment:%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.26.09.png)

# %% [markdown]
# ![%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.28.02.png](attachment:%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.28.02.png)

# %% [markdown]
# # Lists

# %% [markdown]
# * Lists are also ordered sequences
# * Here is a list "L"
# * A list is reoresented with square beackest
# * List is MUTABLE
#
# ![%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.31.06.png](attachment:%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.31.06.png)

# %% [markdown]
# Same as tuples, we can access elements through index:
#
# ![%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.32.59.png](attachment:%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.32.59.png)

# %% [markdown]
# In python, we can use a negative index. The relationship is as follows:
#
# ![%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.34.17.png](attachment:%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.34.17.png)

# %% [markdown]
# ### extend and append
# if we use L.extend, we have two more elements:
# ![%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.37.50.png](attachment:%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.37.50.png)
# If we use L.append, we get only one more elements:
# ![%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.39.26.png](attachment:%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.39.26.png)

# %% [markdown]
# ## Clone
# For example,
#
# we have a list A = ["hard rock",10,1.2]
#
# We can clone the list A by the following syntax:
#
# B=A[:]
#
# In this way, what we edit to A will not effect B
# ![%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.46.34.png](attachment:%E6%88%AA%E5%B1%8F2020-08-25%E4%B8%8A%E5%8D%8810.46.34.png)
